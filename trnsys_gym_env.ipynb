# %%
import torch as th

from stable_baselines3 import TD3,PPO,SAC,DDPG,A2C

import gym
from gym import error, spaces, utils
from gym.utils import seeding

import subprocess           # to run the TRNSYS simulation
import os
import numpy as np

from time import sleep

from filelocker import FileLock
from filelock import FileLock as FL

import logging

# %%
class trnSYSEnv(gym.Env):
    # metadata = {
    #     "render_modes": [
    #         "human",
    #         "rgb_array",
    #         "state_pixels",
    #     ],
    #     "render_fps": FPS,
    # }
    def __init__(self,  deck, config, render_mode = None, model = "", deck_template = ""):

        self.act_path = "action.txt"
        self.obs_path = "observation.txt"
        self.params_path = "others.txt"
        self.render_mode = render_mode
        self.flag = 'EndOfSimFlag'
        self.state = 'iteration_ready'
        self.is_busy = 'busy'
        self.lock_path = ".lock"

        self.uid = np.random.randint(0,9999)
        self.state = FileLock(self.state)
        self.lock = FileLock(self.lock_path)
        self.act_lock = FL(self.act_path + self.lock_path)
        self.obs_lock = FL(self.obs_path + self.lock_path)

        self.config = config
        self.config['obs'] = self.obs_path
        self.prev_action = [0]
        self.proc = None
        # self.model_file = model
        self.deck_file = deck
        # self.deck_template = deck_template

        # # Action
        # self.acts  = self.config['act']
        # lower = [x[0] for x in self.acts.values()]
        # upper = [x[1] for x in self.acts.values()]
        # self.action_space = spaces.Box(np.array(lower), np.array(upper))
        self.action_space = spaces.Box(np.array([-1,]), np.array([1,]))
        
        # Observation
        # obs = np.loadtxt(self.config['obs'], delimiter='	  ', skiprows=1)
        # obs.min(axis=0)
        # obs.max(axis=0)
        # self.observation_space = spaces.Box(np.array([obs.min(axis=0)]*len(obs)), np.array([obs.max(axis=0)]*len(obs)))
        self.observation_space = spaces.Box(np.array([-50, -1500, -10]), np.array([50, 1500, 10]))
        

        pass
    def step(self, act):

        with self.act_lock:
            np.savetxt(self.act_path, np.array(act)) # assuming near-zero writing to file
            
        self.state.release()
        with self.obs_lock:
            obs = np.loadtxt(self.config['obs']).tolist()#, delimiter='	  ', skiprows=1))
            # other parameters
            params = np.loadtxt(self.params_path).tolist()

            energy_consumed = params[0]
            weight_ctrl = params[1]
            weight_energy = params[2]
        # self.lock.acquire()
        
        # Reward compute
        reward_error = obs[0]**2
        reward_ctrl = weight_ctrl * self.prev_action[0]**2
        reward_energy = weight_energy * energy_consumed**2

        reward =  -(reward_error + reward_ctrl + reward_energy)

        done = False
        self.prev_action = act
        # if the simulation is done
        if (os.path.isfile(self.flag) or (self.proc.poll() is not None) ):
            done = True
            # os.remove(self.flag)

        info = list(act)
        # obs, reward, done, info = []
        while(os.path.isfile(self.is_busy + self.lock_path)):
            continue
        sleep(0.05)
        return obs, reward, done, {}
    
    def reset(self):
        # REMOVE EXISTING OBSERVATION from previous run
        if(os.path.isfile(self.obs_path)):
            os.remove(self.obs_path)

        if self.proc is not None:
            # kill existing process
            if self.proc.poll() is None:
                self.proc.kill()
        # start another trnSYS process
        if (self.render_mode is None):
            self.proc = subprocess.Popen([self.config['trnsys_path'], os.path.abspath(self.deck_file),"/h", "/n"])#
        else:
            self.proc = subprocess.Popen([self.config['trnsys_path'], os.path.abspath(self.deck_file), "/n"])#

        self.lock.acquire()
        # not the best if you have alternative method
        # with self.act_lock:
        #     tmp = np.random.randn(1)
        #     print(tmp)
        #     np.savetxt(self.act_path, tmp) 
        # waiting for observation from trnSYS
        while(not os.path.isfile(self.obs_path)):
            continue
        with self.obs_lock:
            obs = np.loadtxt(self.config['obs']).tolist()#, delimiter='	  ', skiprows=1))

        # while self.lock.is_lock():
        #     continue

        # lock action
        return obs
        

    def render(self):
        
        pass
    
    def close(self):
        if self.proc.poll() is None:
            self.proc.kill()
            
        if(os.path.isfile(self.obs_path)):
            os.remove(self.obs_path)
        if(os.path.isfile(self.act_path)):
            os.remove(self.act_path)
        pass

# %%
act_obs_config  = {
    'trnsys_path' : 'C:\TRNSYS18Demo\Exe\TrnEXE64.exe',
    'act' : {
    # variable: [min, max]
            'pyt_t_on':[0.0, 10.0],
            'pyt_t_off':[20.0, 25.0],
            'pyt_s_high':[0.0, 1.0],
            'pyt_s_low':[0.0, 1.0],
    },
    'obs' : 'example_trnsysmodel\\trnOut_PumpData.txt',
    'reward_funct':'np.exp(-np.sum(obs))'
}

# %%
deck =' D E M O V E R S I O N - CoolingHouseSwitchAbleCtrl.dck'
# deck ='C:\TRNSYSproject\YeojuRL\Yeoju.dck'
env = trnSYSEnv(deck, act_obs_config)#, render_mode='human')
# Out:
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
obs = env.reset()
obs
# Out:
# [20.0, 0.0, 20.0]

# %%
# act = env.action_space.sample()
act = np.array([-1])
out = env.step(act.tolist())
[act, out]
# Out:
# [array([-1]),
#  ([47.1804230594292, 5912.465313828656, 5.2648416398569395],
#   -2225.992320066719,
#   True,
#   {})]

# %%
logging.basicConfig(filename='obs.log', level=logging.DEBUG)

# %%
for i in range(80):
    act = env.action_space.sample()
    act
    obs, reward, done, info = env.step(act.tolist())
    logging.debug(obs)
    logging.debug(reward)
    logging.debug(act)
    if(done):
        env.reset()
    # sleep(0.1)

# %%
env.close()

# %%
# Custom actor (pi) and value function (vf) networks
# of two layers of size 32 each with Relu activation function
# Note: an extra linear layer will be added on top of the pi and the vf nets, respectively
no = 1
policy_kwargs = dict(activation_fn=th.nn.ReLU,
                     net_arch=dict(pi=[no], vf=[no], qf=[no]))

# %%
# import stable baselines & train
# ,
log_dir = 'tmp'
model = TD3("MlpPolicy", env, verbose=1, tensorboard_log= log_dir +'/results/')#, policy_kwargs=policy_kwargs)#, use_expln=True)#, features_extractor_kwargs=None)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000)#, reset_num_timesteps=False)
# Out:
# Logging to tmp/results/TD3_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -5.53e+05 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 4         |
# |    time_elapsed    | 71        |
# |    total_timesteps | 324       |
# | train/             |           |
# |    actor_loss      | 7.65e+03  |
# |    critic_loss     | 1.23e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 162       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -6.86e+05 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 4         |
# |    time_elapsed    | 141       |
# |    total_timesteps | 648       |
# | train/             |           |
# |    actor_loss      | 1.36e+04  |
# |    critic_loss     | 4.79e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 486       |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.1     |
# |    ep_rew_mean     | -7.3e+05 |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 4        |
# |    time_elapsed    | 201      |
# |    total_timesteps | 973      |
# | train/             |          |
# |    actor_loss      | 1.72e+04 |
# |    critic_loss     | 8.12e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 810      |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81.1      |
# |    ep_rew_mean     | -7.52e+05 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 5         |
# |    time_elapsed    | 258       |
# |    total_timesteps | 1297      |
# | train/             |           |
# |    actor_loss      | 2.13e+04  |
# |    critic_loss     | 1.14e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1135      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.65e+05 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 5         |
# |    time_elapsed    | 314       |
# |    total_timesteps | 1621      |
# | train/             |           |
# |    actor_loss      | 2.77e+04  |
# |    critic_loss     | 2e+07     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1459      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.74e+05 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 5         |
# |    time_elapsed    | 374       |
# |    total_timesteps | 1945      |
# | train/             |           |
# |    actor_loss      | 3.46e+04  |
# |    critic_loss     | 3.38e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1783      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | -7.8e+05 |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 5        |
# |    time_elapsed    | 434      |
# |    total_timesteps | 2269     |
# | train/             |          |
# |    actor_loss      | 4.13e+04 |
# |    critic_loss     | 5.28e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2107     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.85e+05 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 5         |
# |    time_elapsed    | 491       |
# |    total_timesteps | 2593      |
# | train/             |           |
# |    actor_loss      | 4.85e+04  |
# |    critic_loss     | 6.66e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2431      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.89e+05 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 5         |
# |    time_elapsed    | 545       |
# |    total_timesteps | 2917      |
# | train/             |           |
# |    actor_loss      | 5.59e+04  |
# |    critic_loss     | 1e+08     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2755      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.92e+05 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 5         |
# |    time_elapsed    | 600       |
# |    total_timesteps | 3241      |
# | train/             |           |
# |    actor_loss      | 6.35e+04  |
# |    critic_loss     | 1.16e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3079      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.94e+05 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 5         |
# |    time_elapsed    | 654       |
# |    total_timesteps | 3565      |
# | train/             |           |
# |    actor_loss      | 7.02e+04  |
# |    critic_loss     | 1.6e+08   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3403      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.96e+05 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 5         |
# |    time_elapsed    | 710       |
# |    total_timesteps | 3889      |
# | train/             |           |
# |    actor_loss      | 7.85e+04  |
# |    critic_loss     | 1.61e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3727      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.98e+05 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 5         |
# |    time_elapsed    | 764       |
# |    total_timesteps | 4213      |
# | train/             |           |
# |    actor_loss      | 8.54e+04  |
# |    critic_loss     | 2.04e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4051      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -7.99e+05 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 5         |
# |    time_elapsed    | 819       |
# |    total_timesteps | 4537      |
# | train/             |           |
# |    actor_loss      | 9.23e+04  |
# |    critic_loss     | 2.13e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4375      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.01e+05 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 5         |
# |    time_elapsed    | 874       |
# |    total_timesteps | 4861      |
# | train/             |           |
# |    actor_loss      | 9.96e+04  |
# |    critic_loss     | 2.19e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.02e+05 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 5         |
# |    time_elapsed    | 929       |
# |    total_timesteps | 5185      |
# | train/             |           |
# |    actor_loss      | 1.07e+05  |
# |    critic_loss     | 2.47e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5023      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.03e+05 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 5         |
# |    time_elapsed    | 984       |
# |    total_timesteps | 5509      |
# | train/             |           |
# |    actor_loss      | 1.13e+05  |
# |    critic_loss     | 2.61e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5347      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.04e+05 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 5         |
# |    time_elapsed    | 1041      |
# |    total_timesteps | 5833      |
# | train/             |           |
# |    actor_loss      | 1.21e+05  |
# |    critic_loss     | 2.69e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5671      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.04e+05 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 5         |
# |    time_elapsed    | 1096      |
# |    total_timesteps | 6157      |
# | train/             |           |
# |    actor_loss      | 1.27e+05  |
# |    critic_loss     | 2.59e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5995      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.05e+05 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 5         |
# |    time_elapsed    | 1151      |
# |    total_timesteps | 6481      |
# | train/             |           |
# |    actor_loss      | 1.35e+05  |
# |    critic_loss     | 2.36e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6319      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.06e+05 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 5         |
# |    time_elapsed    | 1215      |
# |    total_timesteps | 6805      |
# | train/             |           |
# |    actor_loss      | 1.42e+05  |
# |    critic_loss     | 3.07e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6643      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.06e+05 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 5         |
# |    time_elapsed    | 1271      |
# |    total_timesteps | 7129      |
# | train/             |           |
# |    actor_loss      | 1.48e+05  |
# |    critic_loss     | 2.38e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6967      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.07e+05 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 5         |
# |    time_elapsed    | 1327      |
# |    total_timesteps | 7453      |
# | train/             |           |
# |    actor_loss      | 1.56e+05  |
# |    critic_loss     | 1.91e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7291      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.07e+05 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 5         |
# |    time_elapsed    | 1382      |
# |    total_timesteps | 7777      |
# | train/             |           |
# |    actor_loss      | 1.61e+05  |
# |    critic_loss     | 1.69e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7615      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.08e+05 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 5         |
# |    time_elapsed    | 1437      |
# |    total_timesteps | 8101      |
# | train/             |           |
# |    actor_loss      | 1.67e+05  |
# |    critic_loss     | 1.89e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7939      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 5         |
# |    time_elapsed    | 1492      |
# |    total_timesteps | 8425      |
# | train/             |           |
# |    actor_loss      | 1.74e+05  |
# |    critic_loss     | 2.09e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8263      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 5         |
# |    time_elapsed    | 1545      |
# |    total_timesteps | 8749      |
# | train/             |           |
# |    actor_loss      | 1.81e+05  |
# |    critic_loss     | 1.47e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8587      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 5         |
# |    time_elapsed    | 1602      |
# |    total_timesteps | 9073      |
# | train/             |           |
# |    actor_loss      | 1.86e+05  |
# |    critic_loss     | 1.86e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8911      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 5         |
# |    time_elapsed    | 1659      |
# |    total_timesteps | 9397      |
# | train/             |           |
# |    actor_loss      | 1.92e+05  |
# |    critic_loss     | 1.54e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9235      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 5         |
# |    time_elapsed    | 1713      |
# |    total_timesteps | 9721      |
# | train/             |           |
# |    actor_loss      | 1.97e+05  |
# |    critic_loss     | 1.27e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9559      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 5         |
# |    time_elapsed    | 1768      |
# |    total_timesteps | 10045     |
# | train/             |           |
# |    actor_loss      | 2.03e+05  |
# |    critic_loss     | 9.68e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9883      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 5         |
# |    time_elapsed    | 1824      |
# |    total_timesteps | 10369     |
# | train/             |           |
# |    actor_loss      | 2.09e+05  |
# |    critic_loss     | 8.5e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10207     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 5         |
# |    time_elapsed    | 1878      |
# |    total_timesteps | 10693     |
# | train/             |           |
# |    actor_loss      | 2.14e+05  |
# |    critic_loss     | 7.92e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10531     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 5         |
# |    time_elapsed    | 1932      |
# |    total_timesteps | 11017     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 7.5e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10855     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 5         |
# |    time_elapsed    | 1987      |
# |    total_timesteps | 11341     |
# | train/             |           |
# |    actor_loss      | 2.26e+05  |
# |    critic_loss     | 6.67e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11179     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 5         |
# |    time_elapsed    | 2041      |
# |    total_timesteps | 11665     |
# | train/             |           |
# |    actor_loss      | 2.29e+05  |
# |    critic_loss     | 4.83e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11503     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 5         |
# |    time_elapsed    | 2097      |
# |    total_timesteps | 11989     |
# | train/             |           |
# |    actor_loss      | 2.35e+05  |
# |    critic_loss     | 2.92e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11827     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 5         |
# |    time_elapsed    | 2152      |
# |    total_timesteps | 12313     |
# | train/             |           |
# |    actor_loss      | 2.4e+05   |
# |    critic_loss     | 2.77e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12151     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 5         |
# |    time_elapsed    | 2207      |
# |    total_timesteps | 12637     |
# | train/             |           |
# |    actor_loss      | 2.42e+05  |
# |    critic_loss     | 4.09e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12475     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 5         |
# |    time_elapsed    | 2262      |
# |    total_timesteps | 12961     |
# | train/             |           |
# |    actor_loss      | 2.51e+05  |
# |    critic_loss     | 2e+07     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 5         |
# |    time_elapsed    | 2317      |
# |    total_timesteps | 13285     |
# | train/             |           |
# |    actor_loss      | 2.54e+05  |
# |    critic_loss     | 1.86e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13123     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 5         |
# |    time_elapsed    | 2372      |
# |    total_timesteps | 13609     |
# | train/             |           |
# |    actor_loss      | 2.6e+05   |
# |    critic_loss     | 1.87e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13447     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 5         |
# |    time_elapsed    | 2427      |
# |    total_timesteps | 13933     |
# | train/             |           |
# |    actor_loss      | 2.64e+05  |
# |    critic_loss     | 2.08e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13771     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 5         |
# |    time_elapsed    | 2481      |
# |    total_timesteps | 14257     |
# | train/             |           |
# |    actor_loss      | 2.68e+05  |
# |    critic_loss     | 1.95e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14095     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 5         |
# |    time_elapsed    | 2537      |
# |    total_timesteps | 14581     |
# | train/             |           |
# |    actor_loss      | 2.73e+05  |
# |    critic_loss     | 3.45e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14419     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 5         |
# |    time_elapsed    | 2593      |
# |    total_timesteps | 14905     |
# | train/             |           |
# |    actor_loss      | 2.75e+05  |
# |    critic_loss     | 1.94e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14743     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 5         |
# |    time_elapsed    | 2648      |
# |    total_timesteps | 15229     |
# | train/             |           |
# |    actor_loss      | 2.79e+05  |
# |    critic_loss     | 3.83e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15067     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 5         |
# |    time_elapsed    | 2701      |
# |    total_timesteps | 15553     |
# | train/             |           |
# |    actor_loss      | 2.84e+05  |
# |    critic_loss     | 3.87e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15391     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 5         |
# |    time_elapsed    | 2754      |
# |    total_timesteps | 15877     |
# | train/             |           |
# |    actor_loss      | 2.89e+05  |
# |    critic_loss     | 2.01e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15715     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 5         |
# |    time_elapsed    | 2805      |
# |    total_timesteps | 16201     |
# | train/             |           |
# |    actor_loss      | 2.92e+05  |
# |    critic_loss     | 2.41e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16039     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 5         |
# |    time_elapsed    | 2857      |
# |    total_timesteps | 16525     |
# | train/             |           |
# |    actor_loss      | 2.92e+05  |
# |    critic_loss     | 4.1e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16363     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 5         |
# |    time_elapsed    | 2908      |
# |    total_timesteps | 16849     |
# | train/             |           |
# |    actor_loss      | 2.98e+05  |
# |    critic_loss     | 2.11e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16687     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 5         |
# |    time_elapsed    | 2961      |
# |    total_timesteps | 17173     |
# | train/             |           |
# |    actor_loss      | 3.03e+05  |
# |    critic_loss     | 2.73e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17011     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 5         |
# |    time_elapsed    | 3013      |
# |    total_timesteps | 17497     |
# | train/             |           |
# |    actor_loss      | 3.06e+05  |
# |    critic_loss     | 2.6e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17335     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 5         |
# |    time_elapsed    | 3067      |
# |    total_timesteps | 17821     |
# | train/             |           |
# |    actor_loss      | 3.08e+05  |
# |    critic_loss     | 5.11e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17659     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 5         |
# |    time_elapsed    | 3119      |
# |    total_timesteps | 18145     |
# | train/             |           |
# |    actor_loss      | 3.11e+05  |
# |    critic_loss     | 2.27e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17983     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 5         |
# |    time_elapsed    | 3172      |
# |    total_timesteps | 18469     |
# | train/             |           |
# |    actor_loss      | 3.13e+05  |
# |    critic_loss     | 2.92e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18307     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 5         |
# |    time_elapsed    | 3224      |
# |    total_timesteps | 18793     |
# | train/             |           |
# |    actor_loss      | 3.16e+05  |
# |    critic_loss     | 3.41e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18631     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 5         |
# |    time_elapsed    | 3277      |
# |    total_timesteps | 19117     |
# | train/             |           |
# |    actor_loss      | 3.2e+05   |
# |    critic_loss     | 3.32e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18955     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 5         |
# |    time_elapsed    | 3330      |
# |    total_timesteps | 19441     |
# | train/             |           |
# |    actor_loss      | 3.26e+05  |
# |    critic_loss     | 2.64e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19279     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 5         |
# |    time_elapsed    | 3381      |
# |    total_timesteps | 19765     |
# | train/             |           |
# |    actor_loss      | 3.22e+05  |
# |    critic_loss     | 1.74e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19603     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 5         |
# |    time_elapsed    | 3433      |
# |    total_timesteps | 20089     |
# | train/             |           |
# |    actor_loss      | 3.26e+05  |
# |    critic_loss     | 3.2e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19927     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 5         |
# |    time_elapsed    | 3486      |
# |    total_timesteps | 20413     |
# | train/             |           |
# |    actor_loss      | 3.32e+05  |
# |    critic_loss     | 2.2e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 5         |
# |    time_elapsed    | 3538      |
# |    total_timesteps | 20737     |
# | train/             |           |
# |    actor_loss      | 3.32e+05  |
# |    critic_loss     | 3.49e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20575     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 5         |
# |    time_elapsed    | 3592      |
# |    total_timesteps | 21061     |
# | train/             |           |
# |    actor_loss      | 3.37e+05  |
# |    critic_loss     | 2.07e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20899     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 5         |
# |    time_elapsed    | 3645      |
# |    total_timesteps | 21385     |
# | train/             |           |
# |    actor_loss      | 3.38e+05  |
# |    critic_loss     | 1.72e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21223     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 5         |
# |    time_elapsed    | 3698      |
# |    total_timesteps | 21709     |
# | train/             |           |
# |    actor_loss      | 3.42e+05  |
# |    critic_loss     | 2.27e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21547     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 5         |
# |    time_elapsed    | 3750      |
# |    total_timesteps | 22033     |
# | train/             |           |
# |    actor_loss      | 3.42e+05  |
# |    critic_loss     | 2.13e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21871     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 5         |
# |    time_elapsed    | 3803      |
# |    total_timesteps | 22357     |
# | train/             |           |
# |    actor_loss      | 3.43e+05  |
# |    critic_loss     | 2.17e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22195     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 5         |
# |    time_elapsed    | 3855      |
# |    total_timesteps | 22681     |
# | train/             |           |
# |    actor_loss      | 3.44e+05  |
# |    critic_loss     | 1.84e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22519     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 5         |
# |    time_elapsed    | 3908      |
# |    total_timesteps | 23005     |
# | train/             |           |
# |    actor_loss      | 3.41e+05  |
# |    critic_loss     | 2.52e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22843     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 5         |
# |    time_elapsed    | 3959      |
# |    total_timesteps | 23329     |
# | train/             |           |
# |    actor_loss      | 3.51e+05  |
# |    critic_loss     | 3.1e+07   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23167     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 5         |
# |    time_elapsed    | 4013      |
# |    total_timesteps | 23653     |
# | train/             |           |
# |    actor_loss      | 3.48e+05  |
# |    critic_loss     | 2.83e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23491     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 5         |
# |    time_elapsed    | 4068      |
# |    total_timesteps | 23977     |
# | train/             |           |
# |    actor_loss      | 3.52e+05  |
# |    critic_loss     | 1.94e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23815     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 5         |
# |    time_elapsed    | 4123      |
# |    total_timesteps | 24301     |
# | train/             |           |
# |    actor_loss      | 3.52e+05  |
# |    critic_loss     | 1.68e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24139     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 5         |
# |    time_elapsed    | 4176      |
# |    total_timesteps | 24625     |
# | train/             |           |
# |    actor_loss      | 3.53e+05  |
# |    critic_loss     | 3.95e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24463     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 5         |
# |    time_elapsed    | 4230      |
# |    total_timesteps | 24949     |
# | train/             |           |
# |    actor_loss      | 3.53e+05  |
# |    critic_loss     | 2.08e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24787     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 5         |
# |    time_elapsed    | 4284      |
# |    total_timesteps | 25273     |
# | train/             |           |
# |    actor_loss      | 3.57e+05  |
# |    critic_loss     | 1.95e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25111     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 5         |
# |    time_elapsed    | 4338      |
# |    total_timesteps | 25601     |
# | train/             |           |
# |    actor_loss      | 3.55e+05  |
# |    critic_loss     | 2.97e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25435     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 5         |
# |    time_elapsed    | 4391      |
# |    total_timesteps | 25925     |
# | train/             |           |
# |    actor_loss      | 3.58e+05  |
# |    critic_loss     | 2e+07     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25763     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 5         |
# |    time_elapsed    | 4446      |
# |    total_timesteps | 26249     |
# | train/             |           |
# |    actor_loss      | 3.6e+05   |
# |    critic_loss     | 2.31e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26087     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 328       |
# |    fps             | 5         |
# |    time_elapsed    | 4502      |
# |    total_timesteps | 26573     |
# | train/             |           |
# |    actor_loss      | 3.63e+05  |
# |    critic_loss     | 1.76e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26411     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 5        |
# |    time_elapsed    | 4558     |
# |    total_timesteps | 26910    |
# | train/             |          |
# |    actor_loss      | 3.6e+05  |
# |    critic_loss     | 3.12e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26735    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 5        |
# |    time_elapsed    | 4610     |
# |    total_timesteps | 27234    |
# | train/             |          |
# |    actor_loss      | 3.64e+05 |
# |    critic_loss     | 1.77e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27072    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 5        |
# |    time_elapsed    | 4663     |
# |    total_timesteps | 27563    |
# | train/             |          |
# |    actor_loss      | 3.66e+05 |
# |    critic_loss     | 1.71e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27401    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 5        |
# |    time_elapsed    | 4714     |
# |    total_timesteps | 27887    |
# | train/             |          |
# |    actor_loss      | 3.63e+05 |
# |    critic_loss     | 2.97e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27725    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 5        |
# |    time_elapsed    | 4765     |
# |    total_timesteps | 28211    |
# | train/             |          |
# |    actor_loss      | 3.65e+05 |
# |    critic_loss     | 2.57e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28049    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 5        |
# |    time_elapsed    | 4817     |
# |    total_timesteps | 28535    |
# | train/             |          |
# |    actor_loss      | 3.71e+05 |
# |    critic_loss     | 2.05e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28373    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 5        |
# |    time_elapsed    | 4868     |
# |    total_timesteps | 28859    |
# | train/             |          |
# |    actor_loss      | 3.62e+05 |
# |    critic_loss     | 2.54e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28697    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 5        |
# |    time_elapsed    | 4919     |
# |    total_timesteps | 29183    |
# | train/             |          |
# |    actor_loss      | 3.66e+05 |
# |    critic_loss     | 1.85e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29021    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 5        |
# |    time_elapsed    | 4972     |
# |    total_timesteps | 29507    |
# | train/             |          |
# |    actor_loss      | 3.7e+05  |
# |    critic_loss     | 2.37e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29345    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -8.2e+05 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 5        |
# |    time_elapsed    | 5025     |
# |    total_timesteps | 29831    |
# | train/             |          |
# ...
# | train/             |           |
# |    actor_loss      | 3.73e+05  |
# |    critic_loss     | 1.52e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42822     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 532       |
# |    fps             | 3         |
# |    time_elapsed    | 12992     |
# |    total_timesteps | 43308     |
# | train/             |           |
# |    actor_loss      | 3.73e+05  |
# |    critic_loss     | 1.66e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43146     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 536       |
# |    fps             | 3         |
# |    time_elapsed    | 13048     |
# |    total_timesteps | 43632     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.45e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43470     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 540       |
# |    fps             | 3         |
# |    time_elapsed    | 13103     |
# |    total_timesteps | 43956     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.27e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43794     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 544       |
# |    fps             | 3         |
# |    time_elapsed    | 13159     |
# |    total_timesteps | 44280     |
# | train/             |           |
# |    actor_loss      | 3.74e+05  |
# |    critic_loss     | 2.55e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44118     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 548       |
# |    fps             | 3         |
# |    time_elapsed    | 13215     |
# |    total_timesteps | 44604     |
# | train/             |           |
# |    actor_loss      | 3.66e+05  |
# |    critic_loss     | 1.33e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44442     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 552       |
# |    fps             | 3         |
# |    time_elapsed    | 13271     |
# |    total_timesteps | 44928     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 1.76e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44766     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 556       |
# |    fps             | 3         |
# |    time_elapsed    | 13326     |
# |    total_timesteps | 45252     |
# | train/             |           |
# |    actor_loss      | 3.72e+05  |
# |    critic_loss     | 1.55e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45090     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 560       |
# |    fps             | 3         |
# |    time_elapsed    | 13382     |
# |    total_timesteps | 45576     |
# | train/             |           |
# |    actor_loss      | 3.67e+05  |
# |    critic_loss     | 3e+07     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45414     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 564       |
# |    fps             | 3         |
# |    time_elapsed    | 13440     |
# |    total_timesteps | 45900     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 1.47e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45738     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 568       |
# |    fps             | 3         |
# |    time_elapsed    | 13500     |
# |    total_timesteps | 46224     |
# | train/             |           |
# |    actor_loss      | 3.7e+05   |
# |    critic_loss     | 2.93e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46062     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 572       |
# |    fps             | 3         |
# |    time_elapsed    | 13558     |
# |    total_timesteps | 46548     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.63e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46386     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 576       |
# |    fps             | 3         |
# |    time_elapsed    | 13617     |
# |    total_timesteps | 46872     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.61e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46710     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 580       |
# |    fps             | 3         |
# |    time_elapsed    | 13676     |
# |    total_timesteps | 47196     |
# | train/             |           |
# |    actor_loss      | 3.66e+05  |
# |    critic_loss     | 1.35e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47034     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 584       |
# |    fps             | 3         |
# |    time_elapsed    | 13735     |
# |    total_timesteps | 47520     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 2.26e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47358     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 588       |
# |    fps             | 3         |
# |    time_elapsed    | 13793     |
# |    total_timesteps | 47844     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.33e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47682     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 592       |
# |    fps             | 3         |
# |    time_elapsed    | 13852     |
# |    total_timesteps | 48169     |
# | train/             |           |
# |    actor_loss      | 3.69e+05  |
# |    critic_loss     | 1.48e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48007     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 596       |
# |    fps             | 3         |
# |    time_elapsed    | 13911     |
# |    total_timesteps | 48493     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 1.31e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48331     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 600       |
# |    fps             | 3         |
# |    time_elapsed    | 13969     |
# |    total_timesteps | 48817     |
# | train/             |           |
# |    actor_loss      | 3.64e+05  |
# |    critic_loss     | 1.59e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48655     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 604       |
# |    fps             | 3         |
# |    time_elapsed    | 14028     |
# |    total_timesteps | 49141     |
# | train/             |           |
# |    actor_loss      | 3.71e+05  |
# |    critic_loss     | 1.53e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48979     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 608       |
# |    fps             | 3         |
# |    time_elapsed    | 14088     |
# |    total_timesteps | 49465     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 1.29e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49303     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.18e+05 |
# | time/              |           |
# |    episodes        | 612       |
# |    fps             | 3         |
# |    time_elapsed    | 14145     |
# |    total_timesteps | 49789     |
# | train/             |           |
# |    actor_loss      | 3.66e+05  |
# |    critic_loss     | 1.42e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49627     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 616       |
# |    fps             | 3         |
# |    time_elapsed    | 14208     |
# |    total_timesteps | 50116     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 3.99e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49951     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81        |
# |    ep_rew_mean     | -8.19e+05 |
# | time/              |           |
# |    episodes        | 620       |
# |    fps             | 3         |
# |    time_elapsed    | 14266     |
# |    total_timesteps | 50440     |
# | train/             |           |
# |    actor_loss      | 3.68e+05  |
# |    critic_loss     | 2.24e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50278     |
# ----------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\genericpath.py in isfile(path)
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'observation.txt'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3c23479a2a57> in <module>
# ----> 1 model.learn(total_timesteps=100_000)#, reset_num_timesteps=False)
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\td3\td3.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     211             tb_log_name=tb_log_name,
#     212             eval_log_path=eval_log_path,
# --> 213             reset_num_timesteps=reset_num_timesteps,
#     214         )
#     215
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     357                 learning_starts=self.learning_starts,
#     358                 replay_buffer=self.replay_buffer,
# --> 359                 log_interval=log_interval,
#     360             )
#     361
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     569
#     570                 # Rescale and perform action
# --> 571                 new_obs, reward, done, infos = env.step(action)
#     572
#     573                 self.num_timesteps += 1
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      47                 # save final observation where user can get it, then reset
#      48                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
#      51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\site-packages\stable_baselines3\common\monitor.py in reset(self, **kwargs)
#      77                 raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      78             self.current_reset_info[key] = value
# ---> 79         return self.env.reset(**kwargs)
#      80
#      81     def step(self, action: Union[np.ndarray, int]) -> GymStepReturn:
#
# <ipython-input-2-3f25d231104a> in reset(self)
#     108         #     np.savetxt(self.act_path, tmp)
#     109         # waiting for observation from trnSYS
# --> 110         while(not os.path.isfile(self.obs_path)):
#     111             continue
#     112         with self.obs_lock:
#
# c:\Users\OBAS\Anaconda3\envs\RL_latest\lib\genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except OSError:
#      32         return False
#
# KeyboardInterrupt:

# %%
# features_extractor
parameters = model.actor.mu.state_dict()
parameters
# Out:
# OrderedDict([('0.weight',
#               tensor([[ 0.0208,  0.4319, -0.4338]], device='cuda:0')),
#              ('0.bias', tensor([0.1341], device='cuda:0')),
#              ('2.weight', tensor([[-0.9426]], device='cuda:0')),
#              ('2.bias', tensor([0.7827], device='cuda:0'))])

# %%
[Kp, Ki] = parameters['0.weight'].tolist()[0]
Kd = parameters['0.bias'].tolist()[0]
[abs(Kp), abs(Ki), abs(Kd)]
